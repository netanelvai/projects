# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

# %%
pg=sns.load_dataset('penguins')

# %%
type(pg)
# Out:
# pandas.core.frame.DataFrame

# %%
pg
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#size of DF
pg.shape
# Out:
# (344, 7)

# %%
pg.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.barplot(x='species',y='body_mass_g',data=pg)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
pg.groupby('species').body_mass_g.mean()
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %%
sns.barplot(x='species',y='body_mass_g',data=pg)
plt.show()

# %%
sns.barplot(x='body_mass_g',y='species',data=pg)
plt.show()

# %%
sns.set_style('darkgrid')
sns.barplot(x='species',y='body_mass_g',data=pg)
plt.show()

# %%
pg_color={'Adelie':'#FFFFCC',
          'Chinstrap':'#1C81A5',
          'Gentoo':'#65A51C'
        }

# %%
sns.set_style('darkgrid')
sns.barplot(x='species',y='body_mass_g',data=pg,palette=pg_color)
plt.show()

# %%
sns.set_style('whitegrid')
sns.barplot(x='species',y='body_mass_g',data=pg,palette=pg_color)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
sns.barplot(x='species',y='body_mass_g',data=pg,palette=pg_color)
plt.show()

# %%
#important 
pg.groupby('species').body_mass_g.describe()
# Out:
#            count         mean         std     min     25%     50%     75%  \
# species
# Adelie     151.0  3700.662252  458.566126  2850.0  3350.0  3700.0  4000.0
# Chinstrap   68.0  3733.088235  384.335081  2700.0  3487.5  3700.0  3950.0
# Gentoo     123.0  5076.016260  504.116237  3950.0  4700.0  5000.0  5500.0
#
#               max
# species
# Adelie     4775.0
# Chinstrap  4800.0
# Gentoo     6300.0

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
sns.barplot(x='species',y='body_mass_g',data=pg,palette=pg_color,estimator=np.min)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
sns.barplot(x='species',y='body_mass_g',data=pg,palette=pg_color,estimator=np.max)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
sns.barplot(x='species',y='body_mass_g',data=pg,hue='sex')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
sns.barplot(x='species',y='body_mass_g',data=pg,hue='sex',order=['Gentoo','Chinstrap','Adelie'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
sns.barplot(x='species',y='body_mass_g',data=pg,hue='sex',order=['Gentoo','Chinstrap','Adelie']
           ,hue_order=['Female','Male'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
sns.barplot(x='species',y='body_mass_g',data=pg,hue='sex',order=['Gentoo','Chinstrap','Adelie']
           ,hue_order=['Female','Male'])
plt.xlabel('types',fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
sns.barplot(x='species',y='body_mass_g',data=pg,hue='sex',order=['Gentoo','Chinstrap','Adelie']
           ,hue_order=['Female','Male'])
plt.xlabel('types',fontsize=14)
plt.ylabel('weight',fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.set_style('whitegrid')
sns.barplot(x='species',y='body_mass_g',data=pg,hue='sex',order=['Gentoo','Chinstrap','Adelie']
           ,hue_order=['Female','Male'])
plt.title('types/avg weight', color='green',fontsize=20)
plt.xlabel('types',fontsize=14)
plt.ylabel('weight',fontsize=12)
plt.show()
